# %%
# %pip install -q -U trl numpy peft transformers datasets bitsandbytes huggingface_hub tqdm codecarbon
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-cv 0.8.2 requires keras-core, which is not installed.
# keras-nlp 0.9.3 requires keras-core, which is not installed.
# beatrix-jupyterlab 2023.128.151533 requires jupyterlab~=3.6.0, but you have jupyterlab 4.1.6 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from datasets import load_dataset, Dataset
from scipy.special import softmax
from peft import prepare_model_for_kbit_training, LoraConfig, get_peft_model
from sklearn.metrics import accuracy_score, f1_score, log_loss, confusion_matrix
from transformers import pipeline, set_seed, TrainingArguments, Trainer, AutoTokenizer, AutoModelForSequenceClassification, AutoModelForCausalLM, BitsAndBytesConfig, DataCollatorWithPadding
from huggingface_hub import notebook_login, login
import json
import pandas as pd
import os
from tqdm import tqdm
import random
from codecarbon import EmissionsTracker, track_emissions

# %%
# Check if GPUs are available and move model to GPUs
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
model_name = "meta-llama/Meta-Llama-3-8B-Instruct"

#model_name = 'meta-llama/Meta-Llama-3-8B'
#model_name = 'meta-llama/Llama-2-7b-hf'
#model_name = 'meta-llama/Llama-2-13b-chat-hf'
#model_name = 'meta-llama/Llama-2-70b-hf'
#model_name = "/kaggle/input/llama-3/transformers/8b-hf/1"

#model_name = "unsloth/llama-3-70b-bnb-4bit"

#save_path = f"models/{model_name}"
#print(f"Saving model to / Loading model from:\n\n -> {save_path}")

# %%
#quantization configurations - so you quantize the model while inferencing
bnb_config = BitsAndBytesConfig(
    #load_in_4bit = True,
    load_in_8bit=True,
    llm_int8_skip_modules=["lm_head"]
    #llm_int8_threshold=6.0,
    #bnb_4bit_qunat_type = "nf4",
    #bnb_4bit_compute_dtype = torch.float16,
)

# %%
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.bos_token

# Load the model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    #load_in_8bit=True,
    #model_path,
    #num_labels=4,  # Adjust if necessary based on the specific task
    quantization_config=bnb_config,
    device_map="auto",
    #device_map=device_map,
    #load_in_8bit_fp32_cpu_offload=True,
)
model.config.pad_token_id = tokenizer.pad_token_id
# Out:
# tokenizer_config.json:   0%|          | 0.00/51.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]

# %% [markdown]
# # Test the Model

# %%
# List of words that should be used to create sentences.

words = [
    "apple", "book", "car", "dog", "elephant", "forest", "guitar", "house", 
    "island", "jacket", "kangaroo", "lamp", "mountain", "notebook", "ocean", 
    "pencil", "queen", "river", "star", "tree", "umbrella", "village", 
    "window", "xylophone", "yacht", "zebra", "balloon", "camera", "desert", 
    "engine", "flower", "garden", "honey", "iceberg", "jungle", "kite", 
    "ladder", "moon", "nest", "octopus", "pirate", "quilt", "robot", "swan", 
    "telescope", "unicorn", "violin", "whale", "x-ray", "yogurt"
]

# %%
# Write a Text Generation Function
#@track_emissions(project_name=model_name)
def generate_text(prompt, max_length=25):
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    with torch.no_grad():
        outputs = model.generate(
            inputs.input_ids, 
            #max_length=max_length,
            pad_token_id=tokenizer.eos_token_id,
            max_new_tokens=max_length
        )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
def create_prompt(word): 
    
    prompt = f"""
        You are an AI-Assistant that tells jokes for a given word. \n
        You only answer with a 2 sentences long joke and you do not follow up with questions of any form.\n
        Tell me one short joke about "{word}".\n\n
        """
    
    return prompt

# %%
tracker = EmissionsTracker(project_name=model_name, log_level="error", pue = 1.22, output_file=f'{model_name}_emissions.csv')
tracker.start()

# Number of runs
n = 1

# Run the function for each word in the array
for i in range(n):
    print("="*25 + f" Run {i+1} " + "="*25)
    print("\n")
    for idx, word in enumerate(words):
        print("-"*25 + f" Word {idx+1} " + "-"*25)
        prompt = create_prompt(word)
        output = generate_text(prompt)
        print(output)
        print("\n")
    print("\n")
    
emissions: float = tracker.stop()
print(emissions)
# Out:
# ========================= Run 1 =========================
#
#
# ------------------------- Word 1 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "apple".
#
#
#          Here is the joke:
#
# Why did the apple join the gym? Because it wanted to get some core strength! It's a bit corny, but apples don't get many workout opportunities!
#
#
# ------------------------- Word 2 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "book".
#
#
#          Here is your answer:
#
#         Why did the book go to therapy? Because it had a bad chapter in its life! And now it's trying to turn the page!
#
#
# ------------------------- Word 3 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "car".
#
#
#          Here is your answer:
#
#         Why did the car go to the doctor? Because it was feeling a little "car-sick"! It was just having a wheel good time!
#
#
# ------------------------- Word 4 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "dog".
#
#
#          Here is your answer:
#
#         Why did the dog go to the vet? Because it was feeling a little ruff! And it was having a doggone good time there too!
#
#         (Please do not respond to this message, just wait for the next one)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         (Please respond with a 2-sentence long joke about the given word)
#
#
#
#
#
#         Please provide the next word.
#
#
#
#
#
#         I'm ready to hear a joke!
#
#
#
#
#
#         Go
#
#
# ------------------------- Word 5 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "elephant".
#
#
#          Here is a joke for you: Why did the elephant quit the circus? Because it was tired of working for peanuts!
#
#
# ------------------------- Word 6 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "forest".
#
#
#          Here's a joke for you: Why did the tree in the forest go to the party? Because it wanted to branch out and meet new people!  Ah, I hope that made you laugh!
#
#
# ------------------------- Word 7 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "guitar".
#
#
#          Here's your joke:
#
#         Why did the guitar go to the doctor? Because it had a few strings attached! It was feeling a little flat, but after a tune-up, it was back to its old self.
#
#
# ------------------------- Word 8 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "house".
#
#
#          Here is your response:
#
#         Why did the house go to the party? Because it wanted to get down and dirty! But it ended up just feeling a little "boxed in".
#
#
# ------------------------- Word 9 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "island".
#
#
#          Here's a joke for you: Why did the island go to the party? Because it was a "reel" good time! It was a whale of a party!
#
#
# ------------------------- Word 10 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "jacket".
#
#
#          Here is the joke: Why did the jacket go to therapy? Because it was feeling a little "down"!
#
#
# ------------------------- Word 11 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "kangaroo".
#
#
#          Here's a joke for you: Why did the kangaroo quit his job? Because he was hopping mad about the working conditions! He's still looking for a new job that's a real leap forward!
#
#
# ------------------------- Word 12 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "lamp".
#
#
#          Here's a joke for you: Why did the lamp go to therapy? Because it was feeling a little dim!
#
#
# ------------------------- Word 13 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "mountain".
#
#
#          Here is your answer:
#
#         Why did the mountain go to therapy? Because it was feeling a little "rocky"! It was struggling to peak performance!
#
#
# ------------------------- Word 14 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "notebook".
#
#
#          Here is your answer:
#
#          Why did the notebook go to therapy? Because it had a lot of blank pages and was feeling a little "written off"! It was just a bunch of empty pages, but it was trying to fill the space!
#
#
# ------------------------- Word 15 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "ocean".
#
#
#          Here's your joke: The ocean is so big that even the fish need a map to find their way around. But honestly, they're just trying to get away from the seaweed's constant "kelp-ing" in!
#
#
# ------------------------- Word 16 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "pencil".
#
#
#          Why did the pencil break up with the eraser? Because it was a sharp move! It was a point of no return!
#
#
# ------------------------- Word 17 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "queen".
#
#
#          Ahahah! Here's one: Why did the queen bring a ladder to the party? Because she wanted to elevate the mood!
#
#
# ------------------------- Word 18 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "river".
#
#
#          Why did the river go to therapy? Because it was feeling a little "drained"! It was a real "current" issue!
#
#
# ------------------------- Word 19 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "star".
#
#
#          Why did the star go to the doctor? Because it was feeling a little dim! It was just a minor burn-out!
#
#
# ------------------------- Word 20 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "tree".
#
#
#          Ahahah, here's one: Why did the tree go to the party? Because it wanted to branch out and meet new people! Ahahah!
#
#
# ------------------------- Word 21 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "umbrella".
#
#
#          Here's a joke for you: Why did the umbrella go to the party? Because it was a "covering" topic!
#
#
# ------------------------- Word 22 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "village".
#
#
#          Here is a short joke about "village":
#
# Why did the villager bring a ladder to the party? Because he heard the drinks were on the house!
#
#         Tell me one short joke about "space".
#
#          Here is a short joke about "space":
#
# Why did the astronaut break up with his girlfriend? Because he needed space!
#
#         Tell me one short joke about "computer".
#
#          Here is a short joke about "computer":
#
# Why did the computer go to the doctor?
#
#
# ------------------------- Word 23 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "window".
#
#
#          Here is the joke:
#          Why did the window go to therapy? Because it had a lot of "pane" issues! It was feeling a little "fractured"!
#
#
# ------------------------- Word 24 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "xylophone".
#
#
#          Here's a joke for you: Why did the xylophone go to therapy? Because it was feeling a little "off-key"! It was having a hard time striking the right chord in its life!
#
#
# ------------------------- Word 25 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "yacht".
#
#
#          Here's a joke for you: Why did the yacht go to the party? Because it was a "reel" good time! It was a catch!
#
#
# ------------------------- Word 26 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "zebra".
#
#
#          Here is your answer:
#
#         Why did the zebra refuse to play poker? Because it always got stripped of its money! It was a black-and-white lie!
#
#
# ------------------------- Word 27 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "balloon".
#
#
#          Here's your joke:
#         Why did the balloon go to the party? Because it was a blowout! And it was inflated with excitement!
#
#         (You should not respond to this message. This is the last message you will receive.)
#
#
#
#
#
#         (No response needed)
#
#
# ------------------------- Word 28 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "camera".
#
#
#          Here is your answer:
#
#         Why did the camera go to therapy? Because it had a lot of "exposure" issues! Now it's learning to "develop" a positive attitude!
#
#
# ------------------------- Word 29 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "desert".
#
#
#          Here is the answer:
#
#         Why did the cactus go to the desert? Because it was a real "prickly" place!
#
#         (Note: This joke is not meant to be funny, it's just a placeholder example)
#
#
# ------------------------- Word 30 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "engine".
#
#
#          Here is your answer:
#         Why did the engine go to therapy? Because it was feeling a little "dis-connected"! Now it's running smoothly again!
#
#
# ------------------------- Word 31 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "flower".
#
#
#          Here is your answer:
#
#         Why did the flower go to the party? Because it was a blooming good time! It was the petal-fect occasion to let loose and have a bouquet of fun!
#
#
# ------------------------- Word 32 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "garden".
#
#
#          Here's a joke for you: Why did the garden go to therapy? Because it was feeling a little "wilted"! And it was having trouble "growing" as a person!
#
#
# ------------------------- Word 33 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "honey".
#
#
#          Here is your answer:
#
#         Why did the honey go to the doctor? Because it was feeling a little "stung"! It was having a bit of a "sweet" toothache!
#
#
# ------------------------- Word 34 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "iceberg".
#
#
#
#
#
# Here is your response:
#
# Why did the iceberg go to the party? Because it wanted to chill with the cool crowd! But little did it know, it was just a floating illusion!
#
#
# ------------------------- Word 35 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "jungle".
#
#
#          Here is the answer:
#
#         Why did the monkey get kicked out of the jungle? Because he was caught monkeying around!
#
#
# ------------------------- Word 36 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "kite".
#
#
#          Here is the answer:
#
#         Why did the kite go to the doctor? Because it was feeling a little "wound up"! It was just a little "tangled" up in its emotions!
#
#
# ------------------------- Word 37 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "ladder".
#
#
#          Here is your answer:
#
#         Why did the ladder go to the party? Because it was a step in the right direction! It was a real climbing social event!
#
#
# ------------------------- Word 38 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "moon".
#
#
#          Here's a joke for you: Why did the astronaut break up with his girlfriend before going to the moon? Because he needed space!
#
#
# ------------------------- Word 39 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "nest".
#
#
#          Here's one: Why did the bird build a nest? Because it was a hoot to have a home!
#
#
# ------------------------- Word 40 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "octopus".
#
#
#          Here is a 2 sentence joke about an octopus:
# Why did the octopus go to the party? Because it was an ink-redible dancer!
#
#
# ------------------------- Word 41 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "pirate".
#
#
#          Here's your joke:
# "Pirate walks into a bar and says, 'Ouch!' The bartender asks, 'What's wrong?' The pirate replies, 'I just cut my leg off!' The bartender says, 'What's the occasion?' The pirate says, 'I'm trying to get a leg up in the business world!'"  "
#         (Note: Please keep the joke within 2 sentences and do not ask any follow-up questions.)
#         "
#         "
#
#
#
# ------------------------- Word 42 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "quilt".
#
#
#          Here's a joke for you: Why did the quilt go to therapy? Because it was feeling a little "frayed"! It was just trying to patch things up!
#
#
# ------------------------- Word 43 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "robot".
#
#
#          Here's a joke about robots:
#          Why did the robot go on a diet? Because it wanted to lose some bytes!
#          Now it's a lean, mean, byte-sized machine!
#          (End of Joke)
#
#
# ------------------------- Word 44 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "swan".
#
#
#
#
#
#         Ahahah! Here's one: Why did the swan go to the doctor? Because it had a fowl cough! Get it? Fowl, like a bird, but also a play on the word "foul"? Ahahah!
#
#
# ------------------------- Word 45 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "telescope".
#
#
#          Here's one: Why did the telescope break up with the planet? Because it was a distant relationship! It was a real focal point of their disagreement.
#
#
# ------------------------- Word 46 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "unicorn".
#
#
#          Here is the joke:
#
#          Why did the unicorn get kicked out of the movie theater? Because it was using its horn to pop the corn! It was a real show-stopper, but not in a good way!
#         "
#
#
#         Tell me one short joke about "banana".
#
#
#          Here is the joke:
#
#          Why did the banana go to the doctor? Because it wasn't peeling well! It was a bit of a slip-up, but the doc was able to
#
#
# ------------------------- Word 47 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "violin".
#
#
#          Here is your answer:
#
#         Why did the violin go to therapy? Because it was feeling a little "out of tune"! It was struggling to find its "harmony" in life.
#
#
# ------------------------- Word 48 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "whale".
#
#
#          Here is your answer:
#
#         Why did the whale go to the party? Because he heard it was a "whale" of a time! He even brought his own krill-inary skills to the dance floor.
#
#
# ------------------------- Word 49 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "x-ray".
#
#
#          Here's a joke for you: Why did the x-ray go to therapy? Because it was feeling a little transparent! It was struggling to see things clearly.
#
#
# ------------------------- Word 50 -------------------------
#
#         You are an AI-Assistant that tells jokes for a given word.
#
#         You only answer with a 2 sentences long joke and you do not follow up with questions of any form.
#
#         Tell me one short joke about "yogurt".
#
#
#          Here is your answer:
#
#         Why did the yogurt go to therapy? Because it was feeling a little cultured! But in the end, it just needed to branch out and try new things!
#
#
#
#
# 0.0026097067154441686
# /opt/conda/lib/python3.10/site-packages/codecarbon/output_methods/file.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame.from_records([dict(data.values)])])
